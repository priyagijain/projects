# %% [markdown]
# <a href="https://colab.research.google.com/github/priyagijain/projects/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import cv2
from matplotlib import pyplot as plt
from google.colab import files

# Upload the image file
uploaded = files.upload()

# Get the uploaded image file name
image_filename = next(iter(uploaded))

# Read the uploaded image file using cv2.imread
image = cv2.imread(image_filename)

if image is not None:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.imshow(image_rgb)
    plt.axis("off")
    plt.show()
else:
    print(f"Failed to read the image file: {image_filename}")
# Out:
#      <input type="file" id="files-b74191e9-7487-4d2b-b6c9-e9df9592c707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b74191e9-7487-4d2b-b6c9-e9df9592c707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7F5BFD21D7E0>
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7F5C29693A30>
# -1

# %%
#invert image
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7F5C29693460>
# -1

# %%
#blur image
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
cv2_imshow(blurred)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7F5C296933A0>
# -1

# %%
#pencil sketch
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7F5C296926B0>
# -1
